# %%
import ROOT as R
# Out:
# Welcome to JupyROOT 6.24/00

# %%
import MyLibrary
reload(MyLibrary)
from MyLibrary import Sort_keys
from MyLibrary import GetHist
from MyLibrary import DrawTotalDep
from MyLibrary import DrawEdep

from MyLibrary import processes
from MyLibrary import particles

import MyLibrary as MyLib

MyLib.tfile = R.TFile('/Users/cheng/workspace/Data/musrsim-sms/output_musr_1000_Laser_1p2GeV_gmm1e3.root','read')
MyLib.lumi_scale = 6.25e+7/1.e+8

# %%
# injected electrons position
c = R.TCanvas()
xy_in = GetHist('DRZ1_e_m_xy')
xy_in.SetStats(0)
xy_in.GetXaxis().SetRangeUser(-100,100)
xy_in.GetYaxis().SetRangeUser(-100,100)
xy_in.SetTitle('Injected electron postion in DRZ1;x [mm];y[mm]')
xy_in.Draw('COLZ')
c.Draw()

# %%
# injected electrons position
c = R.TCanvas()
c.SetRightMargin(0.15)
xy_in = GetHist('DRZ2_e_m_xy')
xy_in.SetStats(0)
xy_in.GetXaxis().SetRangeUser(-20,80)
xy_in.GetYaxis().SetRangeUser(-100,100)
xy_in.SetTitle('Electrons after magnets in DRZ2;x [mm];y[mm]')

xy_in.Draw('COLZ')
c.Draw()

# %%
f = lambda x : [a[0] for a in x]
print f(Sort_keys(particles,'Detector_{0:}_time'))
print f(Sort_keys(particles,'Detector_{0:}_time_small'))
print f(Sort_keys(particles,'Detector_{0:}_time_tiny'))
# Out:
# ['e_m', 'neutron', 'e_p', 'proton', 'deuteron', 'C12', 'gamma', 'C13', 'pi-', 'pi+', 'alpha', 'mu_p', 'Be8', 'B11', 'C11', 'triton', 'B10', 'B10', 'mu_m', 'Li7', 'Be9', 'Be10', 'Li6', 'Be7', 'B9', 'He3']
# ['e_m', 'neutron', 'e_p', 'proton', 'C12', 'gamma', 'deuteron', 'C13', 'pi-', 'pi+', 'alpha', 'mu_p', 'Be8', 'B11', 'C11', 'B10', 'B10', 'mu_m', 'Li7', 'Be9', 'Li6', 'Be10', 'triton', 'Be7', 'B9', 'He3']
# ['e_m', 'e_p', 'proton', 'neutron', 'C12', 'gamma', 'pi-', 'pi+', 'C13', 'alpha', 'mu_p', 'Be8', 'deuteron', 'B11', 'C11', 'B10', 'B10', 'mu_m', 'Li7', 'Be9', 'Li6', 'Be7', 'Be10', 'triton', 'He3', 'B9']

# %%
# energy deposition in detector
#draw energy deposition
f = lambda x : [a[0] for a in x]
keys = f(Sort_keys(particles,'Detector_{0:}_edep',lambda x:x.GetMean()*x.Integral()))
print keys
tmp_h = 'Detector_{0:}_edep'
xRange = [0,500]
title = 'Energy deposition at scintillator;E (MeV);Events'
c,_ = DrawEdep(tmp_h,xRange,title,rebin=2,particles=keys[:6])
c.SetLogy()
c.Draw()
# Out:
# ['e_m', 'e_p', 'gamma', 'proton', 'deuteron', 'neutron', 'pi+', 'pi-', 'C12', 'alpha', 'C13', 'B11', 'Be8', 'mu_p', 'C11', 'B10', 'B10', 'mu_m', 'Be9', 'Be10', 'Li6', 'triton', 'Li7', 'Be7', 'B9', 'He3']

# %%
f = lambda x : [a[0] for a in x]
tmp_h = 'Detector_From_{0:}_edep'
keys = f(Sort_keys(processes,tmp_h,lambda x:x.GetMean()*x.Integral()))
print keys


xRange = [0,500]
title = 'Energy deposits, decomposed by parent process;E (MeV);Events'
# particles = ['compt','eIoni','conv','initialParticle','phot']
# name_map = ['Compton scattering','Ionisation','#gamma conversion','Initial particle','photo-electric effect']
c,_ = DrawEdep(tmp_h,xRange,title,rebin=2,particles=keys[:6])
c.SetLogy()
c.Draw()
# Out:
# ['eBrem', 'conv', 'annihil', 'compt', 'initialParticle', 'eIoni', 'phot', 'photonNuclear', 'neutronInelastic', 'electronNuclear', 'nCapture', 'Decay', 'protonInelastic', 'hIoni', 'hBertiniCaptureAtRest', 'pi+Inelastic', 'pi-Inelastic', 'muMinusCaptureAtRest', 'muIoni', 'dInelastic', 'tInelastic', 'GammaToMuPair', 'hadElastic', 'lambdaInelastic']

# %%
f = lambda x : [a[0] for a in x]
tmp_h = 'Detector_{0:}_edep'
keys = f(Sort_keys(processes,tmp_h,lambda x:x.GetMean()*x.Integral()))
print keys


xRange = [0,500]
title = 'Energy deposits, decomposed by process;E (MeV);Events'
# particles = ['compt','eIoni','conv','initialParticle','phot']
# name_map = ['Compton scattering','Ionisation','#gamma conversion','Initial particle','photo-electric effect']
c,_ = DrawEdep(tmp_h,xRange,title,rebin=2,particles=keys[:6])
c.SetLogy()
c.Draw()
# Out:
# ['compt', 'conv', 'initialParticle', 'eIoni', 'phot', 'eBrem', 'photonNuclear', 'hadElastic', 'nCapture', 'annihil', 'neutronInelastic', 'Decay', 'hIoni', 'electronNuclear', 'pi+Inelastic', 'protonInelastic', 'muMinusCaptureAtRest', 'pi-Inelastic', 'muIoni', 'hBertiniCaptureAtRest', 'GammaToMuPair', 'dInelastic', 'tInelastic', 'lambdaInelastic']

# %%
xRange = [0,500]
title = 'Total energy deposition at scintillator;E (MeV);Events'
c,_ = DrawTotalDep(xRange,title,rebin=0.,tex_pos=[20,1e6])
c.Draw()

# %%
# energy deposition in detector
#draw energy deposition

canvas = []
__ = []
time_array = ['time','time_small','time_tiny']
xRanges = [[0,100],[0,1],[0,0.1]]
for n in range(3):
    tmp_h = 'Detector_{{0:}}_{0:}'.format(time_array[n])
    xRange = xRanges[n]
    title = 'Hit time at scintillator;time (#mu s);Events'
    f = lambda x : [a[0] for a in x]
    keys = f(Sort_keys(particles,tmp_h,R.TH1F.Integral))
    print keys    
    c,_ = DrawEdep(tmp_h,xRange,title,rebin=2,particles=keys[:5],legPos=[0.6,0.5,0.9,0.9])
    c.SetLogy()
    c.Draw()
    canvas.append(c)
    __.append(_)
# Out:
# ['e_m', 'neutron', 'e_p', 'proton', 'deuteron', 'C12', 'gamma', 'C13', 'pi-', 'pi+', 'alpha', 'mu_p', 'Be8', 'B11', 'C11', 'triton', 'B10', 'B10', 'mu_m', 'Li7', 'Be9', 'Be10', 'Li6', 'Be7', 'B9', 'He3']
# ['e_m', 'neutron', 'e_p', 'proton', 'C12', 'gamma', 'deuteron', 'C13', 'pi-', 'pi+', 'alpha', 'mu_p', 'Be8', 'B11', 'C11', 'B10', 'B10', 'mu_m', 'Li7', 'Be9', 'Li6', 'Be10', 'triton', 'Be7', 'B9', 'He3']
# ['e_m', 'e_p', 'proton', 'neutron', 'C12', 'gamma', 'pi-', 'pi+', 'C13', 'alpha', 'mu_p', 'Be8', 'deuteron', 'B11', 'C11', 'B10', 'B10', 'mu_m', 'Li7', 'Be9', 'Li6', 'Be7', 'Be10', 'triton', 'He3', 'B9']

# %%
# energy deposition in detector
#draw energy deposition

canvas = []
__ = []
time_array = ['time','time_small','time_tiny']
xRanges = [[0,100],[0,1],[0,0.1]]
for n in range(3):
    tmp_h = 'Detector_{{0:}}_{0:}'.format(time_array[n])
    xRange = xRanges[n]
    title = 'Hit time, decomposed by process;time (#mu s);Events'
    f = lambda x : [a[0] for a in x]
    keys = f(Sort_keys(processes,tmp_h,R.TH1F.Integral))
    print keys    
    c,_ = DrawEdep(tmp_h,xRange,title,rebin=2,particles=keys[:5],legPos=[0.6,0.5,0.9,0.9])
    c.SetLogy()
    c.Draw()
    canvas.append(c)
    __.append(_)
# Out:
# ['compt', 'photonNuclear', 'conv', 'neutronInelastic', 'eIoni', 'initialParticle', 'hadElastic', 'phot', 'nCapture', 'electronNuclear', 'protonInelastic', 'hBertiniCaptureAtRest', 'eBrem', 'pi-Inelastic', 'pi+Inelastic', 'muMinusCaptureAtRest', 'annihil', 'Decay', 'dInelastic', 'hIoni', 'muIoni', 'tInelastic', 'lambdaInelastic', 'GammaToMuPair']
# ['compt', 'conv', 'photonNuclear', 'neutronInelastic', 'eIoni', 'initialParticle', 'hadElastic', 'phot', 'eBrem', 'electronNuclear', 'hBertiniCaptureAtRest', 'protonInelastic', 'nCapture', 'pi-Inelastic', 'annihil', 'pi+Inelastic', 'muMinusCaptureAtRest', 'Decay', 'dInelastic', 'hIoni', 'muIoni', 'tInelastic', 'lambdaInelastic', 'GammaToMuPair']
# ['compt', 'conv', 'eIoni', 'initialParticle', 'phot', 'hadElastic', 'photonNuclear', 'neutronInelastic', 'eBrem', 'annihil', 'electronNuclear', 'Decay', 'hIoni', 'muIoni', 'protonInelastic', 'muMinusCaptureAtRest', 'pi-Inelastic', 'hBertiniCaptureAtRest', 'pi+Inelastic', 'nCapture', 'GammaToMuPair']

# %%
# energy deposition in detector
#draw energy deposition

canvas = []
__ = []
time_array = ['time','time_small','time_tiny']
xRanges = [[0,100],[0,1],[0,0.1]]
for n in range(3):
    tmp_h = 'Detector_From_{{0:}}_{0:}'.format(time_array[n])
    xRange = xRanges[n]
    title = 'Hit time, decomposed by parent process;time (#mu s);Events'
    f = lambda x : [a[0] for a in x]
    keys = f(Sort_keys(processes,tmp_h,R.TH1F.Integral))
    print keys    
    c,_ = DrawEdep(tmp_h,xRange,title,rebin=2,particles=keys[:5],legPos=[0.6,0.5,0.9,0.9])
    c.SetLogy()
    c.Draw()
    canvas.append(c)
    __.append(_)
# Out:
# ['eBrem', 'photonNuclear', 'conv', 'annihil', 'neutronInelastic', 'compt', 'eIoni', 'initialParticle', 'phot', 'electronNuclear', 'protonInelastic', 'hBertiniCaptureAtRest', 'pi-Inelastic', 'pi+Inelastic', 'nCapture', 'muMinusCaptureAtRest', 'dInelastic', 'Decay', 'hIoni', 'muIoni', 'tInelastic', 'lambdaInelastic', 'hadElastic', 'GammaToMuPair']
# ['eBrem', 'conv', 'annihil', 'photonNuclear', 'compt', 'neutronInelastic', 'eIoni', 'initialParticle', 'phot', 'electronNuclear', 'protonInelastic', 'hBertiniCaptureAtRest', 'nCapture', 'pi-Inelastic', 'pi+Inelastic', 'muMinusCaptureAtRest', 'Decay', 'dInelastic', 'hIoni', 'muIoni', 'tInelastic', 'lambdaInelastic', 'hadElastic', 'GammaToMuPair']
# ['eBrem', 'conv', 'annihil', 'compt', 'eIoni', 'initialParticle', 'phot', 'photonNuclear', 'neutronInelastic', 'electronNuclear', 'nCapture', 'hBertiniCaptureAtRest', 'protonInelastic', 'muMinusCaptureAtRest', 'Decay', 'pi-Inelastic', 'pi+Inelastic', 'hIoni', 'muIoni', 'dInelastic', 'hadElastic', 'GammaToMuPair']

# %%
# energy deposition in detector
#draw energy deposition

canvas = []
__ = []
time_array = ['time','time_small','time_tiny']
xRanges = [[0,20],[0,1],[0,0.1]]
for n in range(3):
    tmp_h = 'Detector_From_{{0:}}_e_m_{0:}'.format(time_array[n])
    xRange = xRanges[n]
    title = 'Electrons hit time;time (#mu s);Events'
    
    f = lambda x : [a[0] for a in x]
    keys = f(Sort_keys(processes,tmp_h,R.TH1F.Integral))
    print keys
    c,_ = DrawEdep(tmp_h,xRange,title,rebin=2,particles=keys[:6],legPos=[0.6,0.5,0.9,0.9])
    c.SetLogy()
    c.Draw()
    canvas.append(c)
    __.append(_)
# Out:
# ['eBrem', 'annihil', 'conv', 'compt', 'eIoni', 'initialParticle', 'phot', 'photonNuclear', 'nCapture', 'neutronInelastic', 'electronNuclear', 'hBertiniCaptureAtRest', 'protonInelastic', 'Decay', 'hIoni', 'pi-Inelastic', 'muIoni', 'pi+Inelastic', 'muMinusCaptureAtRest', 'dInelastic', 'tInelastic', 'GammaToMuPair']
# ['eBrem', 'annihil', 'conv', 'compt', 'eIoni', 'initialParticle', 'phot', 'photonNuclear', 'neutronInelastic', 'nCapture', 'electronNuclear', 'hBertiniCaptureAtRest', 'protonInelastic', 'hIoni', 'pi-Inelastic', 'Decay', 'muIoni', 'pi+Inelastic', 'muMinusCaptureAtRest', 'dInelastic', 'tInelastic', 'GammaToMuPair']
# ['eBrem', 'annihil', 'conv', 'compt', 'eIoni', 'initialParticle', 'phot', 'photonNuclear', 'neutronInelastic', 'electronNuclear', 'nCapture', 'hBertiniCaptureAtRest', 'protonInelastic', 'hIoni', 'muIoni', 'Decay', 'pi-Inelastic', 'pi+Inelastic', 'muMinusCaptureAtRest', 'dInelastic', 'GammaToMuPair']

# %%
xRange = [0,100]
title = 'Hit time distribution;time (#mu s);Events'
canvas = []
__ = []
time_array = ['time','time_small','time_tiny']
xRanges = [[0,100],[0,1],[0,0.1]]
for n in range(3):
    c,_ = DrawTotalDep(xRange,title,rebin=0,hist_name='Detector_{0:}'.format(time_array[n]),draw_tex=False)
    canvas.append(c);__.append(_)
    c.Draw()

# %%
def wrapper(rangex):
    def cmp(hist):
        if rangex[1]<10:
            return hist.Integral()
        else:
            integral = hist.Integral(hist.GetXaxis().FindBin(30),hist.GetXaxis().FindBin(80))
            return integral
    return cmp                

xRange = [0,100]
title = 'Hit time distribution;time (#mu s);Edep (MeV)'
canvas = []
__ = []
time_array = ['time_edep','time_small_edep','time_tiny_edep']
xRanges = [[1,10],[0,1],[0,0.1]]
for n in range(3):
    c,_ = DrawTotalDep(xRanges[n],title,rebin=5,hist_name='Detector_{0:}'.format(time_array[n]),draw_tex=False)
    canvas.append(c);__.append(_)
    c.Draw()

# %%
R.gStyle.SetPaintTextFormat('.e')
c = R.TCanvas('c1','c1',1200,800)
c.SetLeftMargin(0.2)
h = GetHist('Cutflow_2D_Detector_Particle_vs_Process')
h.SetTitle('Scintillator: Particles and their creators')
c.SetLogz(1)
h.SetStats(0)
h.SetLabelSize(0.05)
h.GetYaxis().SetLabelSize(0.05)
h.Draw('text COLZ')
h.SetTitle

c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
c = R.TCanvas('c2','c2',1200,800)
c.SetLogz(1)
c.SetLeftMargin(0.2)
h = GetHist('Cutflow_2D_Detector_Particle_vs_ParentProcess')
h.SetStats(0)
h.SetLabelSize(0.05)
h.GetYaxis().SetLabelSize(0.05)
h.Draw('text COLZ')
h.SetTitle

c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
c = R.TCanvas('c3','c3',1200,800)
c.SetLeftMargin(0.2)
c.SetLogz(1)
h = GetHist('Cutflow_2D_Detector_Particle_vs_ParentParticle')
h.SetStats(0)
h.SetLabelSize(0.05)
h.GetYaxis().SetLabelSize(0.05)
h.Draw('text COLZ')
h.SetTitle

c.Draw()

# %%
c = R.TCanvas('c3','c3',1200,800)
c.SetLeftMargin(0.2)
c.SetLogz(1)
h = GetHist('Cutflow_2D_Detector_ParentParticle_vs_ParentProcess')
h.SetTitle('Target: Particles and their creators')
h.SetStats(0)
h.SetLabelSize(0.05)
h.GetYaxis().SetLabelSize(0.05)
h.Draw('text COLZ')
h.SetTitle

c.Draw()

# %%
title = '#gamma #rightarrow #mu#mu process;time (#mu s);Edep / time (MeV / #mu s)'
canvas = []
__ = []
xRange = [0,10]
tmp_h = 'Detector_From_GammaToMuPair_{0:}_time_edep'
keys = ['e_p_From_mu_p','e_m_From_mu_m','mu_m']
c,_ = DrawEdep(tmp_h,xRange,title,rebin=5,particles=keys,legPos=[0.6,0.5,0.9,0.9],scale_by_binW=True)
c.SetLogy(1)
canvas.append(c);__.append(_)
c.Draw()

# %%
title = '#mu from hadron decay;time (#mu s);Edep / time (MeV / #mu s)'
canvas = []
__ = []
xRange = [0,10]
tmp_h = 'Detector_From_Decay_{0:}_time_edep'
keys = ['e_m_From_mu_m','e_p_From_mu_p']
c,_ = DrawEdep(tmp_h,xRange,title,rebin=5,particles=keys,legPos=[0.6,0.5,0.9,0.9],scale_by_binW=True)
c.SetLogy(1)
canvas.append(c);__.append(_)
c.Draw()
