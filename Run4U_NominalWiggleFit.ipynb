# %%
import ROOT as R
R.gROOT.Macro('/Users/cheng/test/rootlogon.C')
R.gStyle.SetOptFit(1111111)
R.gStyle.SetFitFormat('g')
# Out:
# Welcome to JupyROOT 6.24/06
#
# Welcome to the ROOT tutorials
#
#
# Type ".x demos.C" to get a toolbar from which to execute the demos
#
# Type ".x demoshelp.C" to see the help window
#
# ==> Many tutorials use the file hsimple.root produced by hsimple.C
# ==> It is recommended to execute hsimple.C before any other script

# %%
R.gStyle.SetStatX(0.9)
R.gStyle.SetStatY(0.9)
R.gStyle.SetStatH(0.09)
R.gStyle.SetStatW(0.2)



# A method seed 84
file_name = '/Users/cheng/WorkRun23/output/Run2all_Amethod_seed_84/result_28paras_run23_sjtu_Run2all_Amethod_seed84.root'
f = R.TFile(file_name)

h = f.Get('wiggle_28paras_run23_sjtu_Run2all_Amethod_seed84')
h.SetTitle('Run2all A-method;Time [#mu s];N')
h.SetName('Run2all A-method 28 paras fitting')

c = R.TCanvas('c1','c1',1200,800)
c.SetLogy(1)
h.Draw()
c.Draw()

# %%
R.gStyle.SetStatX(0.9)
R.gStyle.SetStatY(0.9)
R.gStyle.SetStatH(0.09)
R.gStyle.SetStatW(0.2)



# A method seed 84
file_name = '/Users/cheng/WorkRun23/output/Run4U_Tmethod_gain_A_Scan_fixseed_adhoc1.root'
f = R.TFile(file_name)

h = f.Get('wiggle_28paras_run23_sjtu_Run4U_Tmethod_gain_A_10')
h.SetTitle('Run4U T-method;Time [#mu s];N')
h.SetName('Run4U T-method 28 paras fitting')

c = R.TCanvas('c1','c1',1200,800)
c.SetLogy(1)
h.Draw()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
R.gStyle.SetStatX(0.9)
R.gStyle.SetStatY(0.9)
R.gStyle.SetStatH(0.09)
R.gStyle.SetStatW(0.2)



# A method seed 84
file_name = '/Users/cheng/WorkRun23/output/Run4U_Tmethod_gain_A_Scan_Run4U_preliminary.root'
f = R.TFile(file_name)

h = f.Get('wiggle_28paras_run23_sjtu_Run4U_Tmethod_gain_A_10')
h.SetTitle('Run4U T-method;Time [#mu s];N')
h.SetName('Run4U T-method 28 paras fitting')

c = R.TCanvas('c1','c1',1200,800)

c.SetLogy(1)
h.Draw()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
