# %%
import ROOT as R
import tools
from tools import DrawSensitivity
DrawSensitivity = tools.DrawSensitivity
tools.version = 'FixedPU_adhoc1'
# Out:
# Welcome to JupyROOT 6.24/06

# %%
method = 'A'
syst = 'gain_A'
cs = DrawSensitivity(method,syst,[0.5,2.])

# %%
method = 'A'
syst = 'gain_T'
cs = DrawSensitivity(method,syst,[0.,2.0])

# %%
method = 'A'
syst = 'stdp_A'
cs = DrawSensitivity(method,syst,[0.,2.])

# %%
method = 'A'
syst = 'stdp_T'
cs = DrawSensitivity(method,syst,[0.,2])

# %%
method = 'T'
syst = 'gain_A'
cs = DrawSensitivity( method,syst,[0.,2.] )

# %%
method = 'T'
syst = 'gain_T'
cs = DrawSensitivity(method,syst,[0.,2.])

# %%
method = 'T'
syst = 'stdp_A'
cs = DrawSensitivity(method,syst,[0,2])

# %%
method = 'T'
syst = 'stdp_T'
cs = DrawSensitivity(method,syst,[0.,2])
