# %%
from imp import reload
import ROOT as R
import tools
reload(tools)
from tools import DrawSensitivity

DrawSensitivity = tools.DrawSensitivity
tools.version = 'FullRun2'
tools.dataset = 'Run2All'
tools.isSave = True
tools.saveDir = './plots/%s_%s/'%(tools.version,tools.dataset)

# %%
method = 'A'
syst = 'gain_A'
cs = DrawSensitivity(method,syst,[0.5,1.5])
# Out:
# Chi2 = 1.03463415581987 at 1.0
# Sensitivity = 0.10075513355580767 +- 0.4359188528185713
# Info in <TCanvas::Print>: png file ./plots/FullRun2_Run2All//Run2All_Amethod_gain_A_sensitivity.png has been created
# Info in <TCanvas::Print>: png file ./plots/FullRun2_Run2All//Run2All_Amethod_gain_A_Chi2.png has been created

# %%
method = 'A'
syst = 'gain_T'
cs = DrawSensitivity(method,syst,[0.5,1.5])
# Out:
# Chi2 = 1.034634155980475 at 1.0
# Sensitivity = 0.23912013223744566 +- 0.43281341325370104

# %%
method = 'A'
syst = 'stdp_A'
cs = DrawSensitivity(method,syst,[0.5,1.5])
# Out:
# Chi2 = 1.0345346930795585 at 1.49
# Sensitivity = 0.002912976129444189 +- 0.428367204785193

# %%
method = 'A'
syst = 'stdp_T'
cs = DrawSensitivity(method,syst,[0.5,1.5])
# Out:
# Chi2 = 1.034497019478916 at 1.49
# Sensitivity = 0.004159043335512536 +- 0.4324420776210651

# %%
method = 'T'
syst = 'gain_A'
cs = DrawSensitivity( method,syst,[0.5,1.5] )
# Out:
# Chi2 = 1.0220274933740414 at 0.9
# Sensitivity = 0.09262315259211817 +- 0.4703672945868248

# %%
method = 'T'
syst = 'gain_T'
cs = DrawSensitivity(method,syst,[0.5,1.5])
# Out:
# Chi2 = 1.0236599854279143 at 1.0
# Sensitivity = 0.2406752548389619 +- 0.4847937240478775

# %%
method = 'T'
syst = 'stdp_A'
cs = DrawSensitivity(method,syst,[0.5,1.5])
# Out:
# Chi2 = 1.0235608597085335 at 0.5
# Sensitivity = 0.0021510359198018136 +- 0.457792525943753

# %%
method = 'T'
syst = 'stdp_T'
cs = DrawSensitivity(method,syst,[0.5,1.5])
# Out:
# Chi2 = 1.0235838187437791 at 0.5
# Sensitivity = 0.003438073648069917 +- 0.4758078627159395
